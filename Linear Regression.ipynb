# %% [markdown]
# * First Module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\H S COMPUTER S HYD\Desktop\\Colories.csv")

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df.head(5)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
y=df.iloc[:,-1]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df["Duration"]

# %%
x=pd.DataFrame(np.array(x).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([120.3373149 , 350.55267561, 120.3373149 , 264.22191534,
#        177.89115508, 264.22191534, 264.22191534, 350.55267561,
#        177.89115508, 350.55267561, 350.55267561, 695.87571668,
#        350.55267561, 120.3373149 , 350.55267561, 350.55267561,
#        264.22191534, 523.21419614, 350.55267561, 350.55267561,
#        264.22191534, 264.22191534, 350.55267561, 350.55267561,
#        350.55267561, 177.89115508, 523.21419614, 120.3373149 ,
#        264.22191534, 350.55267561, 350.55267561, 177.89115508,
#        926.09107739])

# %%
y_test
# Out:
# 139     222.4
# 119     332.7
# 135     189.0
# 57      305.0
# 98      188.2
# 31      180.1
# 162     270.0
# 53      486.0
# 104      92.7
# 150     343.0
# 20      364.2
# 87     1000.1
# 15      215.2
# 68      110.4
# 25      250.0
# 32      299.0
# 136     317.7
# 108     500.3
# 157     270.4
# 16      300.0
# 77      300.0
# 19      243.0
# 12      345.3
# 9       269.0
# 33      223.0
# 160     250.4
# 101     500.0
# 58      226.4
# 138     308.0
# 165     300.0
# 144     470.2
# 80      319.2
# 62      853.0
# Name: Calories, dtype: float64

# %%
plt.scatter(x_test,y_test,c="b")
plt.scatter(x_test,y_pred,c="r")
sns.regplot(x=x_test,y=y_test,color="green")
# Out:
# <Axes: xlabel='0', ylabel='Calories'>

# %%
LR.predict([[200]])
# Out:
# array([1156.3064381])

# %% [markdown]
# TASK

# %%
df.head(5)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
x=df["Pulse"]
y=df["Maxpulse"]

# %%
x=pd.DataFrame(np.array(x).reshape(-1,1))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %% [markdown]
# * Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5.623659915859063

# %% [markdown]
# * Root Mean Square Error

# %%
from sklearn.metrics import root_mean_squared_error

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 7.722871156136979

# %% [markdown]
# * R2 ERROR

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.825645350728589

# %%
y_pred
# Out:
# array([163.09304282, 130.32981098, 158.78209126, 140.67609472,
#        135.50295285, 119.12133693, 123.43228849, 143.26266565,
#        120.84571756, 132.91638192, 134.64076254, 127.74324005,
#        126.01885943, 132.91638192, 127.74324005, 128.60543036,
#        142.40047534, 119.12133693, 127.74324005, 127.74324005,
#        136.36514316, 125.15666911, 132.91638192, 126.01885943,
#        121.70790787, 114.81038538, 119.12133693, 173.43932656,
#        138.9517141 , 136.36514316, 158.78209126, 178.61246842,
#        135.50295285])

# %%
y_test
# Out:
# 139    162
# 119    124
# 135    156
# 57     144
# 98     131
# 31     112
# 162    130
# 53     151
# 104    108
# 150    134
# 20     131
# 87     157
# 15     120
# 68     136
# 25     120
# 32     124
# 136    143
# 108    120
# 157    120
# 16     120
# 77     141
# 19     125
# 12     128
# 9      124
# 33     113
# 160    120
# 101    110
# 58     172
# 138    138
# 165    145
# 144    170
# 80     182
# 62     135
# Name: Maxpulse, dtype: int64

# %%
plt.scatter(x_test,y_test,c="b")
plt.scatter(x_test,y_pred,c="r")
sns.regplot(x=x_test,y=y_test,color="green")
# Out:
# <Axes: xlabel='0', ylabel='Maxpulse'>

# %%
LR.predict([[105]])

# %% [markdown]
# * Task

# %%
db=pd.read_csv(r"C:\Users\H S COMPUTER S HYD\Desktop\diabetes_prediction_dataset.csv")

# %%
db.head(5)

# %%
db.drop(["gender","smoking_history","diabetes","hypertension","heart_disease"],axis=1,inplace=True)

# %%
db.head(5)

# %%
sns.heatmap(db.corr(),annot=True)

# %%
y=db["HbA1c_level"]
db.drop("HbA1c_level",axis=1,inplace=True)

# %%
y

# %%
db.head(5)

# %%
x=db
#x=pd.DataFrame(np.array(x).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
n_LR=LinearRegression()

# %%
n_LR.fit(x_train,y_train)

# %%
y_pred=n_LR.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)

# %%
y_pred

# %%
y_test

# %% [markdown]
# * New

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()

# %%
iris["species"]=iris.species.map({'setosa':1, 'versicolor':2, 'virginica':3})

# %%
iris.head(5)

# %%
y=iris["petal_width"]
iris.drop("petal_width",axis=1,inplace=True)

# %%
x=iris

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
new_LR=LinearRegression()

# %%
new_LR.fit(x_train,y_train)

# %%
y_pred=new_LR.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)

# %% [markdown]
# * Ridge

# %%
from sklearn.linear_model import Ridge

# %%
iris_Ridge=Ridge(alpha=1,random_state=42)

# %%
iris_Ridge.fit(x_train,y_train)

# %%
r_pid=iris_Ridge.predict(x_test)

# %%
r2_score(y_test,r_pid)

# %% [markdown]
# * Lasso

# %%
from sklearn.linear_model import Lasso

# %%
iris_lasso=Lasso(alpha=1,random_state=42)

# %%
iris_lasso.fit(x_train,y_train)

# %%
L_pid=iris_lasso.predict(x_train)

# %%
r2_score(y_train,L_pid)

# %% [markdown]
# ### Task

# %%
cl=pd.read_csv(r"C:\Users\H S COMPUTER S HYD\Desktop\Cellphone.csv")

# %%
cl.head(5)

# %%
y=cl["Price"]
cl.drop(["Price","Product_id"],axis=1,inplace=True)

# %%
x=cl

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
new2_LR=LinearRegression()

# %%
new2_LR.fit(x_train,y_train)

# %%
y_pred=new2_LR.predict(x_test)
y_train_pred=new2_LR.predict(x_train)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
print("R2 Test:",r2_score(y_test,y_pred))
print("R2 Train:",r2_score(y_train,y_train_pred))

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
cl_RR=Ridge()

# %%
parameter={
    "alpha":[1,2,3,6,8,9,10],
}
cl_Grid=GridSearchCV(estimator=cl_RR,param_grid=parameter,scoring="r2")

# %%
cl_Grid.fit(x_train,y_train)

# %%
cl_Grid.best_params_

# %%
cl_Grid.best_score_

# %% [markdown]
# * Ridge

# %%
cl_Ridge=Ridge(alpha=1,random_state=42)

# %%
cl_Ridge.fit(x_train,y_train)

# %%
ridge_pid=cl_Ridge.predict(x_test)

# %%
r2_score(y_test,ridge_pid)

# %% [markdown]
# * Lasso

# %%
cl_lasso=Lasso(alpha=1,random_state=42)

# %%
cl_lasso.fit(x_train,y_train)

# %%
Lasso_pid=cl_lasso.predict(x_train)

# %%
r2_score(y_train,Lasso_pid)
